# %% [markdown]
# # Ejercicio Presion hidrostática
#
# ![Screenshot_2.png](attachment:6a396483-0e70-4f8e-8636-7661a250fc8c.png)
#
# >Para la primera parte analizamos las ecuaciones de campo para nuestro fenómeno físico
# $$-\frac{dp}{dx}+o_{x}=0$$ $$-\frac{dp}{dy}+o_{y}=0$$ $$-\frac{dp}{dz}+o_{z}=0$$
# >Donde
# $$o_{z}=-pg$$
# >Por tanto $P=f(z)$
